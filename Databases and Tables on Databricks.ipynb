# %%
# %sql
use catalog my_catalog;

# %%
# %sql
--creation of managed table
create table manadged_default
(length int,width int,height int);

Insert into manadged_default values(1 int,2 int,3 int)

# %%
# %sql
describe extended manadged_default

# %%
# %sql
--creation of external table
create table external_default
(length int,width int,height int) 
location '/my_catalog/external_default'
--after this insert values run the command of describe extened tablename(external default)

# %%
# %sql
drop table manadged_default

# %%
# %fs ls 'my_catalog.default.manadged_default'

# %%
# %sql
create schema new_default

# %%
# %sql
describe database extended new_default

# %%
# %sql
use new_default;

# %%
# %sql
describe extended managed_new_default

# %%
# %sql
drop table managed_new_default;
--after this command run %fs ls pathdirectory
