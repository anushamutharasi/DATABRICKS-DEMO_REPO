# %%
print("databricks from notebook from udemy")

# %%
# %sql
select "Hello wrold from sql"

# %% [markdown]
# # Title1
# ## Title2
# ### Title3
#
# with **bold** text,*italicised* text
#
# Ordered list
# 1. banana
# 1. mango
#
# Unordered list
# * one
# * two
# * three
#
# Images
# ![](https://miro.medium.com/1*BxTA9zYVYtTwwWdSm7drOw.jpeg)
#
#
# Links:
# <a href="https://miro.medium.com/1*BxTA9zYVYtTwwWdSm7drOw.jpeg" teaget="blank">Manage notebook documentaion</a>

# %%
# %sh pwd

# %%
# %run /Workspace/Users/amutharasi@innominds.com/Includes/SetUp

# %%
print(Full_name)
print(coming_from)

# %%
# %fs ls './databricks-datasets'

# %%
dbutils.help()

# %%
dbutils.fs.help()

# %%
files=dbutils.fs.ls("/databricks-datasets")
print(files)

# %%
display(files)
