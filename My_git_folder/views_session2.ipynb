# %% [markdown]
# Next, we are going to demonstrate how tables and views are persisted across multiple sessions and how temporary views are not.
#
# To do so, we are going to create a new notebook,which means a new Spark sessionand explore how our created views will behave there.
#
# Great.
#
# And this new Spark session,let us first run the SHOW TABLES command.
#
# Interesting.The result here confirms that the table smartphonesof course still exist.
#
# Also, as expected, the stored view
# of Apple phones still exist in this new session.
#
# However, the temporary view of phones brands does not exist.
#
# Let us go back to the previous notebook and re-run the SHOW TABLE command.
#
# Again, all these three tables and views from this old session are still here.
#
# Let us go back to the new notebook.
#
# So, temporary views are not accessible, for example,from another notebook as we just did or after detaching and reattaching a notebook to a cluster or after installing a Python package,which is in turn restarts the Python interpreter,or simply after restarting the cluster.
#
# But what about the global temporary view?
#
# Let us run the command SHOW TABLES IN global_temp.
#
# Interesting, our global temporary view still exists.In fact, as long as the cluster is running,the database, global_temp, persists and any notebook attached to the cluster
#
# can access its global temporary views,and we can see this in action by querying this global_temp view in this new session.
#
# Great, here we see our latest phones.
#
# But remember, if you were to restart the cluster,this statement would fail
# because the view will no longer exist.
#
# Let us finally drop our table and views.

# %%
# %sql
use catalog my_catalog

# %%
# %sql
show tables

# %% [markdown]
# if we want we can drop the tables
