# %%
# %sql
USE CATALOG my_catalog;

# %%
# %sql
USE SCHEMA emp_schema;

# %%
# %sql
CREATE TABLE employees
(id int, name STRING,salary double)

# %%
# %sql
INSERT INTO employees VALUES (1,"anu",2300),(2,"anusha",4500);
Insert into employees values (3,"mouni",9000),(4,"mamatha",8999);
INSERT into employees VALUES (5,"john",7654);
INSERT into employees values (6,"anna",554664);

# %%
# %sql
select * from employees;

# %%
# %sql
Describe detail employees

# %%
# %fs ls 'my_catalog.emp_schema.employees'

# %%
# %sql
update employees set salary=salary+100 where name like "%a"

# %%
# %sql
describe detail employees

# %%
# %sql
select * from employees

# %%
# %sql
describe history employees
